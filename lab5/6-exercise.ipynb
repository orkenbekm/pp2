# %% [markdown]
# 6. Write a Python program to replace all occurrences of space, comma, or dot with a colon.

# %%
import re
file = r"C:\Users\Aikorkem\Desktop\STUDY\pp2\labs\lab5\row.txt"
with open(file, "r" , encoding="utf-8") as file:
    row=file.read().splitlines()

# %%
import re
file = r"C:\Users\Aikorkem\Desktop\STUDY\pp2\labs\lab5\row.txt"
with open(file, "r" , encoding="utf-8") as file:
    string_tests=file.read().splitlines()

# %%
pattern=r"[ ,.]"
res=[]
for line in row:
    match=re.sub(pattern,":", line)
    res.extend(match)
print(res)
# Out:
# ['Д', 'У', 'Б', 'Л', 'И', 'К', 'А', 'Т', 'Ф', 'и', 'л', 'и', 'а', 'л', ':', 'Т', 'О', 'О', ':', 'E', 'U', 'R', 'O', 'P', 'H', 'A', 'R', 'M', 'A', ':', 'А', 'с', 'т', 'а', 'н', 'а', 'Б', 'И', 'Н', ':', '0', '8', '0', '8', '4', '1', '0', '0', '0', '7', '6', '1', 'Н', 'Д', 'С', ':', 'С', 'е', 'р', 'и', 'я', ':', '5', '8', '0', '0', '1', ':', '№', ':', '0', '0', '1', '4', '3', '7', '7', 'К', 'а', 'с', 'с', 'а', ':', '3', '0', '0', '-', '1', '8', '9', 'С', 'м', 'е', 'н', 'а', ':', '1', '0', 'П', 'о', 'р', 'я', 'д', 'к', 'о', 'в', 'ы', 'й', ':', 'н', 'о', 'м', 'е', 'р', ':', 'ч', 'е', 'к', 'а', ':', '№', '6', '4', 'Ч', 'е', 'к', ':', '№', '2', '3', '3', '1', '1', '8', '0', '2', '6', '6', 'К', 'а', 'с', 'с', 'и', 'р', ':', 'А', 'п', 'т', 'е', 'к', 'а', ':', '1', '7', '-', '1', 'П', 'Р', 'О', 'Д', 'А', 'Ж', 'А', '1', ':', 'Н', 'а', 'т', 'р', 'и', 'я', ':', 'х', 'л', 'о', 'р', 'и', 'д', ':', '0', ':', '9', '%', ':', ':', '2', '0', '0', ':', 'м', 'л', ':', ':', 'ф', 'л', '2', ':', '0', '0', '0
# ...
